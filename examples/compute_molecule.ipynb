# %%
import sys
sys.path.append('../')

import molecules

# %%
molecule_name = 'LiH'
distance = 2
orbitals_remove = [3]

qubit_op, initial_state = molecules.compute_molecule(molecule_name, distance=distance,
                                                     orbitals_remove=orbitals_remove,
                                                     initial_state=True)

print(qubit_op)
print(initial_state)
# Out:
# -0.004655156793732384 * IZXIZX
# - 0.004655156793732384 * IIXIZX
# + 0.004655156793732384 * IZXIIX
# + 0.004655156793732384 * IIXIIX
# + 0.010300172229711874 * XXXIZX
# - 0.010300172229711874 * YXYIZX
# - 0.010300172229711874 * XXXIIX
# + 0.010300172229711874 * YXYIIX
# + 0.0037049479115422988 * XXZIZX
# + 0.0037049479115422988 * YYIIZX
# - 0.0037049479115422988 * XXZIIX
# - 0.0037049479115422988 * YYIIIX
# - 0.0031968348909468835 * IIIIZX
# + 0.0031968348909468835 * IIIIIX
# - 0.011964438410713022 * ZIIIZX
# + 0.011964438410713022 * ZIIIIX
# + 0.0027958113827302364 * ZZIIZX
# - 0.0027958113827302364 * ZZIIIX
# + 0.0031874306262608637 * IZZIZX
# - 0.0031874306262608637 * IZZIIX
# + 0.014079774138667688 * IIZIZX
# - 0.014079774138667688 * IIZIIX
# + 0.00490175370516447 * IIIZZX
# - 0.00490175370516447 * IIIZIX
# - 0.005404246742172087 * ZXXZXX
# + 0.005404246742172087 * IYYZXX
# - 0.005404246742172087 * ZXXIYY
# + 0.005404246742172087 * IYYIYY
# + 0.004984548579491065 * ZXZZXX
# ...
